# %%
import pyreadr
import pandas as pd
import numpy as np

# %%
fault_free_test = pyreadr.read_r('TEP_FaultFree_Testing.RData')
fault_free_train = pyreadr.read_r('TEP_FaultFree_Training.RData')
faulty_test = pyreadr.read_r('TEP_Faulty_Testing.RData')
faulty_train = pyreadr.read_r('TEP_Faulty_Training.RData')

# %%
fault_free_test
# Out:
# OrderedDict([('fault_free_testing',
#                       faultNumber  simulationRun  sample  xmeas_1  xmeas_2  xmeas_3  \
#               0                 0            1.0       1  0.25171   3672.4   4466.3
#               1                 0            1.0       2  0.25234   3642.2   4568.7
#               2                 0            1.0       3  0.24840   3643.1   4507.5
#               3                 0            1.0       4  0.25153   3628.3   4519.3
#               4                 0            1.0       5  0.21763   3655.8   4571.0
#               ...             ...            ...     ...      ...      ...      ...
#               479995            0          500.0     956  0.26428   3671.5   4510.8
#               479996            0          500.0     957  0.25132   3573.4   4483.9
#               479997            0          500.0     958  0.25105   3622.6   4433.3
#               479998            0          500.0     959  0.24521   3660.5   4485.2
# ...

# %%
fault_free_train
# Out:
# OrderedDict([('fault_free_training',
#                       faultNumber  simulationRun  sample  xmeas_1  xmeas_2  xmeas_3  \
#               0               0.0            1.0       1  0.25038   3674.0   4529.0
#               1               0.0            1.0       2  0.25109   3659.4   4556.6
#               2               0.0            1.0       3  0.25038   3660.3   4477.8
#               3               0.0            1.0       4  0.24977   3661.3   4512.1
#               4               0.0            1.0       5  0.29405   3679.0   4497.0
#               ...             ...            ...     ...      ...      ...      ...
#               249995          0.0          500.0     496  0.29325   3640.1   4473.0
#               249996          0.0          500.0     497  0.29134   3625.7   4506.2
#               249997          0.0          500.0     498  0.29438   3600.2   4478.3
#               249998          0.0          500.0     499  0.25269   3683.5   4486.4
# ...

# %%
faulty_test
# Out:
# OrderedDict([('faulty_testing',
#                        faultNumber  simulationRun  sample  xmeas_1  xmeas_2  xmeas_3  \
#               0                  1            1.0       1  0.25171   3672.4   4466.3
#               1                  1            1.0       2  0.25234   3642.2   4568.7
#               2                  1            1.0       3  0.24840   3643.1   4507.5
#               3                  1            1.0       4  0.25153   3628.3   4519.3
#               4                  1            1.0       5  0.21763   3655.8   4571.0
#               ...              ...            ...     ...      ...      ...      ...
#               9599995           20          500.0     956  0.26494   3719.6   4536.7
#               9599996           20          500.0     957  0.25252   3724.0   4494.3
#               9599997           20          500.0     958  0.25164   3700.8   4537.3
#               9599998           20          500.0     959  0.29097   3641.8   4525.2
# ...

# %%
faulty_train
# Out:
# OrderedDict([('faulty_training',
#                        faultNumber  simulationRun  sample  xmeas_1  xmeas_2  xmeas_3  \
#               0                  1            1.0       1  0.25038   3674.0   4529.0
#               1                  1            1.0       2  0.25109   3659.4   4556.6
#               2                  1            1.0       3  0.25038   3660.3   4477.8
#               3                  1            1.0       4  0.24977   3661.3   4512.1
#               4                  1            1.0       5  0.29405   3679.0   4497.0
#               ...              ...            ...     ...      ...      ...      ...
#               4999995           20          500.0     496  0.23419   3655.3   4461.7
#               4999996           20          500.0     497  0.26704   3647.4   4540.2
#               4999997           20          500.0     498  0.26543   3630.3   4571.6
#               4999998           20          500.0     499  0.27671   3655.7   4498.9
# ...

# %%
fault_free_test['fault_free_testing'].columns
# Out:
# Index(['faultNumber', 'simulationRun', 'sample', 'xmeas_1', 'xmeas_2',
#        'xmeas_3', 'xmeas_4', 'xmeas_5', 'xmeas_6', 'xmeas_7', 'xmeas_8',
#        'xmeas_9', 'xmeas_10', 'xmeas_11', 'xmeas_12', 'xmeas_13', 'xmeas_14',
#        'xmeas_15', 'xmeas_16', 'xmeas_17', 'xmeas_18', 'xmeas_19', 'xmeas_20',
#        'xmeas_21', 'xmeas_22', 'xmeas_23', 'xmeas_24', 'xmeas_25', 'xmeas_26',
#        'xmeas_27', 'xmeas_28', 'xmeas_29', 'xmeas_30', 'xmeas_31', 'xmeas_32',
#        'xmeas_33', 'xmeas_34', 'xmeas_35', 'xmeas_36', 'xmeas_37', 'xmeas_38',
#        'xmeas_39', 'xmeas_40', 'xmeas_41', 'xmv_1', 'xmv_2', 'xmv_3', 'xmv_4',
#        'xmv_5', 'xmv_6', 'xmv_7', 'xmv_8', 'xmv_9', 'xmv_10', 'xmv_11'],
#       dtype='object')

# %%
fault_free_test['fault_free_testing'].describe()
# Out:
#        faultNumber  simulationRun         sample        xmeas_1  \
# count     480000.0  480000.000000  480000.000000  480000.000000
# mean           0.0     250.500000     480.500000       0.250526
# std            0.0     144.337429     277.128268       0.031273
# min            0.0       1.000000       1.000000       0.122610
# 25%            0.0     125.750000     240.750000       0.229390
# 50%            0.0     250.500000     480.500000       0.250520
# 75%            0.0     375.250000     720.250000       0.271600
# max            0.0     500.000000     960.000000       0.390320
#
#              xmeas_2        xmeas_3        xmeas_4        xmeas_5  \
# count  480000.000000  480000.000000  480000.000000  480000.000000
# mean     3663.764171    4508.898696       9.346866      26.902165
# std        33.943033      39.398350       0.086148       0.211148
# min      3503.300000    4338.200000       8.936300      26.018000
# ...

# %%
fault_free_train['fault_free_training'].describe()
# Out:
#        faultNumber  simulationRun         sample        xmeas_1  \
# count     250000.0  250000.000000  250000.000000  250000.000000
# mean           0.0     250.500000     250.500000       0.250482
# std            0.0     144.337567     144.337567       0.030873
# min            0.0       1.000000       1.000000       0.122450
# 25%            0.0     125.750000     125.750000       0.229770
# 50%            0.0     250.500000     250.500000       0.250510
# 75%            0.0     375.250000     375.250000       0.271200
# max            0.0     500.000000     500.000000       0.391740
#
#              xmeas_2       xmeas_3        xmeas_4        xmeas_5  \
# count  250000.000000  250000.00000  250000.000000  250000.000000
# mean     3663.785706    4508.81979       9.347101      26.902196
# std        34.006357      39.21542       0.085721       0.211485
# min      3511.800000    4336.90000       8.972700      25.951000
# ...

# %%
faulty_test['faulty_testing'].describe()
# Out:
#         faultNumber  simulationRun        sample       xmeas_1       xmeas_2  \
# count  9.600000e+06   9.600000e+06  9.600000e+06  9.600000e+06  9.600000e+06
# mean   1.050000e+01   2.505000e+02  4.805000e+02  2.565512e-01  3.665140e+03
# std    5.766282e+00   1.443373e+02  2.771280e+02  1.413868e-01  4.337049e+01
# min    1.000000e+00   1.000000e+00  1.000000e+00 -4.985500e-03  3.308400e+03
# 25%    5.750000e+00   1.257500e+02  2.407500e+02  2.191700e-01  3.637600e+03
# 50%    1.050000e+01   2.505000e+02  4.805000e+02  2.504100e-01  3.664000e+03
# 75%    1.525000e+01   3.752500e+02  7.202500e+02  2.801300e-01  3.690800e+03
# max    2.000000e+01   5.000000e+02  9.600000e+02  1.016800e+00  3.891700e+03
#
#             xmeas_3       xmeas_4       xmeas_5       xmeas_6       xmeas_7  \
# count  9.600000e+06  9.600000e+06  9.600000e+06  9.600000e+06  9.600000e+06
# mean   4.510175e+03  9.389582e+00  2.690135e+01  4.237570e+01  2.725131e+03
# ...

# %%
faulty_train['faulty_training'].describe()
# Out:
#         faultNumber  simulationRun        sample       xmeas_1       xmeas_2  \
# count  5.000000e+06   5.000000e+06  5.000000e+06  5.000000e+06  5.000000e+06
# mean   1.050000e+01   2.505000e+02  2.505000e+02  2.613588e-01  3.663777e+03
# std    5.766282e+00   1.443373e+02  1.443373e+02  1.495384e-01  4.316941e+01
# min    1.000000e+00   1.000000e+00  1.000000e+00 -4.735000e-03  3.327400e+03
# 25%    5.750000e+00   1.257500e+02  1.257500e+02  2.183000e-01  3.636500e+03
# 50%    1.050000e+01   2.505000e+02  2.505000e+02  2.511300e-01  3.663300e+03
# 75%    1.525000e+01   3.752500e+02  3.752500e+02  2.832100e-01  3.690200e+03
# max    2.000000e+01   5.000000e+02  5.000000e+02  1.017500e+00  3.906700e+03
#
#             xmeas_3       xmeas_4       xmeas_5       xmeas_6       xmeas_7  \
# count  5.000000e+06  5.000000e+06  5.000000e+06  5.000000e+06  5.000000e+06
# mean   4.506046e+03  9.370345e+00  2.690156e+01  4.236419e+01  2.723005e+03
# ...

# %%
fault_free_test_description = fault_free_test['fault_free_testing'].describe()
fault_free_train_description = fault_free_train['fault_free_training'].describe()
faulty_test_description = faulty_test['faulty_testing'].describe()
faulty_train_description = faulty_train['faulty_training'].describe()

# %%
fault_free_test_description.to_excel('fault_free_test_description.xlsx')
fault_free_train_description.to_excel('fault_free_train_description.xlsx')
faulty_test_description.to_excel('faulty_test_description.xlsx')
faulty_train_description.to_excel('faulty_train_description.xlsx')

# %%
df_free_train = fault_free_train['fault_free_training']
df_faulty_train = faulty_train['faulty_training']
df_free_test = fault_free_test['fault_free_testing']
df_faulty_test = faulty_test['faulty_testing']

# %%
train_data = pd.concat([df_free_train, df_faulty_train], axis=0, ignore_index=True)
test_data = pd.concat([df_free_test, df_faulty_test], axis=0, ignore_index=True)

# %%
rename_col = {
    'xmeas_1': 'a_feed_stream', 
    'xmeas_2': 'd_feed_stream', 
    'xmeas_3': 'e_feed_stream',
    'xmeas_4': 'a_and_c_feed_stream', 
    'xmeas_5': 'recycle_flow',
    'xmeas_6': 'reactor_feed_rate', 
    'xmeas_7': 'reactor_pressure', 
    'xmeas_8': 'reactor_level',
    'xmeas_9': 'reactor_temp', 
    'xmeas_10': 'purge_rate', 
    'xmeas_11': 'separator_temp',
    'xmeas_12': 'separator_level', 
    'xmeas_13': 'separator_pressure', 
    'xmeas_14': 'separator_underflow',
    'xmeas_15': 'stripper_level', 
    'xmeas_16': 'stripper_pressure', 
    'xmeas_17': 'stripper_underflow',
    'xmeas_18': 'stripper_temperature', 
    'xmeas_19': 'stripper_steam_flow', 
    'xmeas_20': 'compressor_work',
    'xmeas_21': 'reactor_cooling_water_outlet_temp', 
    'xmeas_22': 'condenser_cooling_water_outlet_temp',
    'xmeas_23': 'composition_of_a_rxtr_feed', 
    'xmeas_24': 'composition_of_b_rxtr_feed',
    'xmeas_25': 'composition_of_c_rxtr_feed', 
    'xmeas_26': 'composition_of_D_rxtr_feed',
    'xmeas_27': 'composition_of_e_rxtr_feed', 
    'xmeas_28': 'composition_of_f_rxtr_feed',
    'xmeas_29': 'composition_of_a_purge', 
    'xmeas_30': 'Composition_of_b_purge',
    'xmeas_31': 'composition_of_c_purge', 
    'xmeas_32': 'Composition_of_d_purge',
    'xmeas_33': 'composition_of_e_purge', 
    'xmeas_34': 'Composition_of_f_purge',
    'xmeas_35': 'composition_of_g_purge', 
    'xmeas_36': 'composition_of_h_purge',
    'xmeas_37': 'composition_of_d_product', 
    'xmeas_38': 'composition_of_e_product',
    'xmeas_39': 'composition_of_f_product', 
    'xmeas_40': 'composition_of_g_product',
    'xmeas_41': 'composition_of_h_product',
    'xmv_1': 'd_feed_flow_valve', 
    'xmv_2': 'e_feed_flow_valve', 
    'xmv_3': 'a_feed_flow_valve',
    'xmv_4': 'a_and_c_feed_flow_valve', 
    'xmv_5': 'compressor_recycle_valve',
    'xmv_6': 'purge_valve', 
    'xmv_7': 'separator_pot_liquid_flow_valve',
    'xmv_8': 'stripper_liquid_product_flow_valve', 
    'xmv_9': 'stripper_steam_valve',
    'xmv_10': 'reactor_cooling_water_flow_valve', 
    'xmv_11': 'condenser_cooling_water_flow_valve'
}

# %%
train_data.rename(columns=rename_col, inplace=True)
test_data.rename(columns=rename_col, inplace=True)

# %%
train_data['fault_label'] = (train_data['faultNumber'] != 0).astype(int)
test_data['fault_label'] = (test_data['faultNumber'] != 0).astype(int)

# %%
train_data['fault_label'].value_counts()
# Out:
# fault_label
# 1    5000000
# 0     250000
# Name: count, dtype: int64

# %%
test_data['fault_label'].value_counts()
# Out:
# fault_label
# 1    9600000
# 0     480000
# Name: count, dtype: int64

# %%
train_data.to_csv("train_data.txt", sep='\t', index=False)
test_data.to_csv("test_data.txt", sep='\t', index=False)
